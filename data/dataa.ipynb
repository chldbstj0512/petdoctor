# %%
import pandas as pd

df = pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 1           1  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 2           2  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 3           3  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 4           4  https://kin.naver.com/qna/detail.naver?d1id=8&...
#
#                               title  \
# 0                  고양이 간식 뭍으려함 숨기려함
# 1               수컷 강아지 중성화 후 붉어짐 증상
# 2  4개월 강아지들 다 이런가요? 아니면 유독 얘만 이런겅가?
# 3          암컷 길냥이 중성화 후 다음날 방사 되나요?
# 4                         강아지 구토유발제
#
#                                             question  \
# 0  저희집 고양이가 츄르는 안 먹어서 통조림 주는데 주니까 안 먹고 통조림 숨기려는 모...
# 1  안녕하세요. 11개월 된 수컷 강아지를 4일 전에 중성화 수술하였습니다. (수술 후...
# 2  강아지 4개월 (시바이누) 고양이 5년 (페르시안) 1. 강아지 고양이 합사 (강아...
# 3  사비로 손안타는 길냥이를 잡아서 수술 시켰습니다. 일요일에 입원 시키고 어제 수술 ...
# 4  오늘 강아지가 초콜렛이 든 단백질 쿠키를 몰래 먹어서 바로 동물병원에 데려갔어요 갔...
#
# ...

# %%
df = df.fillna("")   # ★ 필수

# %%
df.to_csv('data.csv')

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0     0
# url            0
# title          0
# question       0
# answer         0
# answer_type    0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 1           1  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 2           2  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 3           3  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 4           4  https://kin.naver.com/qna/detail.naver?d1id=8&...
#
#                               title  \
# 0                  고양이 간식 뭍으려함 숨기려함
# 1               수컷 강아지 중성화 후 붉어짐 증상
# 2  4개월 강아지들 다 이런가요? 아니면 유독 얘만 이런겅가?
# 3          암컷 길냥이 중성화 후 다음날 방사 되나요?
# 4                         강아지 구토유발제
#
#                                             question  \
# 0  저희집 고양이가 츄르는 안 먹어서 통조림 주는데 주니까 안 먹고 통조림 숨기려는 모...
# 1  안녕하세요. 11개월 된 수컷 강아지를 4일 전에 중성화 수술하였습니다. (수술 후...
# 2  강아지 4개월 (시바이누) 고양이 5년 (페르시안) 1. 강아지 고양이 합사 (강아...
# 3  사비로 손안타는 길냥이를 잡아서 수술 시켰습니다. 일요일에 입원 시키고 어제 수술 ...
# 4  오늘 강아지가 초콜렛이 든 단백질 쿠키를 몰래 먹어서 바로 동물병원에 데려갔어요 갔...
#
# ...

# %%
cols = ["url", "title", "question", "answer", "answer_type"]

# %%
df_final = pd.concat(
    [
        df[cols],
        df1[cols]
    ],
    ignore_index=True
)

# %%
df_final.to_csv('data.csv')

# %%
df_final.head()
# Out:
#                                                  url  \
# 0  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 1  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 2  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 3  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 4  https://kin.naver.com/qna/detail.naver?d1id=8&...
#
#                               title  \
# 0                  고양이 간식 뭍으려함 숨기려함
# 1               수컷 강아지 중성화 후 붉어짐 증상
# 2  4개월 강아지들 다 이런가요? 아니면 유독 얘만 이런겅가?
# 3          암컷 길냥이 중성화 후 다음날 방사 되나요?
# 4                         강아지 구토유발제
#
#                                             question  \
# 0  저희집 고양이가 츄르는 안 먹어서 통조림 주는데 주니까 안 먹고 통조림 숨기려는 모...
# 1  안녕하세요. 11개월 된 수컷 강아지를 4일 전에 중성화 수술하였습니다. (수술 후...
# 2  강아지 4개월 (시바이누) 고양이 5년 (페르시안) 1. 강아지 고양이 합사 (강아...
# 3  사비로 손안타는 길냥이를 잡아서 수술 시켰습니다. 일요일에 입원 시키고 어제 수술 ...
# 4  오늘 강아지가 초콜렛이 든 단백질 쿠키를 몰래 먹어서 바로 동물병원에 데려갔어요 갔...
#
#                                               answer answer_type
# ...

# %%
df_final.tail()
# Out:
#       url                                              title  \
# 9788  NaN                                    탈수교정 이후 빈혈수치 하락
# 9789  NaN                                    강아지가 뒷다리를 절뚝거려요
# 9790  NaN                                             강아지 기침
# 9791  NaN                              댕댕이 이렇게 걷는거 괜찮은거맞나요?ㅠ
# 9792  NaN  강아지가 이렇게토해놨어요.. 어제 7시쯤먹은건데.. 변도 약간 질긴한데 설사는아니구...
#
#                                                question  \
# 9788  저번달 극심한 탈수와 전해질 불균형 심함,번수치 급상승,약한 빈혈,방광염,간수치 엄...
# 9789  올해 4살 3~4kg 나가는 푸들인데요 오늘 갑자기 침대위에서 깨갱깨갱거리더니 뒷다...
# 9790  전날까지 아무런 이상도 없고 밥이랑 물도 잘 먹었는데 아침에 보니까 계속 그 사람으...
# 9791  아는지인 여행가서 며칠 봐주는데 저렇게 걸을때 게걸음? 끌면서 걷는거? 다리괜찮은건...
# 9792  강아지가 이렇게토해놨어요.. 어제 7시쯤먹은건데.. 변도 약간 질긴한데 설사는아니구...
#
#                                                  answer answer_type
# 9788  와, 상황이 많이 복잡하고 힘드셨겠네요. 저도 반려동물 키우면서 비슷하게 힘들었던 ...  non_expert
# 9789  우리 강아지도 가끔 갑자기 한쪽 다리 절뚝거릴 때가 있었는데, 그땐 잠깐 삐끗한 것...  non_expert
# ...

# %%
# Out:
# 0.50    0.000060
# 0.95    0.000088
# Name: request_cost, dtype: float64
